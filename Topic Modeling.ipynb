# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

# Load the dataset
file_path = "trump_speeches.csv"  # Replace with "biden_speeches.csv" for Biden's speeches
df = pd.read_csv(file_path)

# Ensure RawText column exists
texts = df['RawText'].fillna("")

# Convert speeches into a document-term matrix
vectorizer = CountVectorizer(stop_words='english', max_features=5000)
dtm = vectorizer.fit_transform(texts)

# Fit LDA model
n_topics = 10  # You can adjust the number of topics
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_model.fit(dtm)

# Display the top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

feature_names = vectorizer.get_feature_names_out()
display_topics(lda_model, feature_names)
# Out:
# Topic 1:
# states united order shall section secretary national act president executive
#
# Topic 2:
# trump donald going don said people right know ll got
#
# Topic 3:
# said people going great know like want don did years
#
# Topic 4:
# applause people know great thank going want don said years
#
# Topic 5:
# th know ve don ll said right like great way
#
# Topic 6:
# election ballots votes people want president vote states won fraud
#
# Topic 7:
# federal law americans life state enforcement health administration today nation
#
# Topic 8:
# president thank ve mr people know going great want just
#
# Topic 9:
# thank applause great american america people united today world nation
#
# Topic 10:
# president going ve think people ll know want don just

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

# Load the dataset
file_path = "biden_speeches.csv"  # Replace with "biden_speeches.csv" for Biden's speeches
df = pd.read_csv(file_path)

# Ensure RawText column exists
texts = df['RawText'].fillna("")

# Convert speeches into a document-term matrix
vectorizer = CountVectorizer(stop_words='english', max_features=5000)
dtm = vectorizer.fit_transform(texts)

# Fit LDA model
n_topics = 10  # You can adjust the number of topics
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_model.fit(dtm)

# Display the top words for each topic
def display_topics(model, feature_names, no_top_words=10):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

feature_names = vectorizer.get_feature_names_out()
display_topics(lda_model, feature_names)
# Out:
# Topic 1:
# people know going president applause thank biden said country think
#
# Topic 2:
# refugee refugees freedom press bosnia genocide nato herzegovina administration today
#
# Topic 3:
# american jobs care workers work people make country america build
#
# Topic 4:
# people vote joe know let president biden care justice election
#
# Topic 5:
# th people nd ng ing like ve know think going
#
# Topic 6:
# nation america trump president world american people united states today
#
# Topic 7:
# women united states health security secretary president global foreign administration
#
# Topic 8:
# president trump people need health american americans covid pandemic care
#
# Topic 9:
# biden federal shall scientific access agency housing latino including ensure
#
# Topic 10:
# honking gun conversations inaudible violence music horns president people hate
